# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig=plt.figure(figsize=(10,4))
a1=fig.add_subplot(2,2,3)
a2=fig.add_subplot(2,2,2)
a3=fig.add_subplot(2,2,4)
a4=fig.add_subplot(2,2,1)
a2.plot(np.random.random(10))
a3.hist(np.random.random(10))
a4.pie(np.arange(5))
 plt.show()
